# %%
# !git clone https://github.com/jeya-maria-jose/Medical-Transformer.git
# Out:
# Cloning into 'Medical-Transformer'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 166 (delta 40), reused 28 (delta 28), pack-reused 111
# Receiving objects: 100% (166/166), 1.19 MiB | 16.26 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !cd /content/Medical-Transformer

# %%
# !pwd
# Out:
# /content

# %%
# !pip install -r ./Medical-Transformer/requirements.txt
# Out:
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from -r ./Medical-Transformer/requirements.txt (line 1)) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from -r ./Medical-Transformer/requirements.txt (line 2)) (0.16.0+cu121)
# Collecting scikit-learn==0.23.2 (from -r ./Medical-Transformer/requirements.txt (line 3))
#   Downloading scikit-learn-0.23.2.tar.gz (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 16.4 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !cat
